# %%
import numpy as np
import pandas as pd
from textblob import TextBlob
import plotly.graph_objects as go
import plotly.express as xp

# %%
modi=pd.read_csv("modi_reviews.csv")
rahul=pd.read_csv("rahul_reviews.csv")

# %%
modi.shape
# Out:
# (25688, 3)

# %%
modi["Tweet"][0]
# Out:
# '@anjanaomkashyap I am seeing you as future #bjp spokesperson..\nGood luck. Anjana Om Modi oops Kashyap.\nJournalists like you changed the meaning of journalism. Janta maaf nai karege'

# %%
modi['Tweet']=modi['Tweet'].astype(str)
rahul['Tweet']=rahul['Tweet'].astype(str)

# %%
TextBlob(modi["Tweet"][0]).sentiment
# Out:
# Sentiment(polarity=0.35, subjectivity=0.36250000000000004)

# %%
TextBlob(rahul["Tweet"][10]).sentiment
# Out:
# Sentiment(polarity=-0.3814697265625, subjectivity=0.375)

# %%
def find_polarity(review):
  return TextBlob(review).sentiment.polarity

# %%
find_polarity('I will like modi to win')
# Out:
# 0.8

# %%
modi['polarity']=modi['Tweet'].apply(find_polarity)

# %%
rahul['polarity']=rahul['Tweet'].apply(find_polarity)

# %%
modi['label']=np.where(modi['polarity']>0,'positive','negative')
rahul['label']=np.where(rahul['polarity']>0,'positive','negative')

# %%
rahul['label'][rahul['polarity']==0]='neutral'
# Out:
# <ipython-input-20-30ff73831579>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rahul['label'][rahul['polarity']==0]='neutral'

# %%
modi['label'][modi['polarity']==0]='neutral'
# Out:
# <ipython-input-21-203e0ac885a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modi['label'][modi['polarity']==0]='neutral'

# %%
modi.sample(5)
# Out:
#        Unnamed: 0             User  \
# 25157       25157  DR_DHIRENDRA_NS
# 13545       13545    RaghuMiskin09
# 8453         8453      muthukumarr
# 13495       13495         kunalIYC
# 5406         5406     DemoCrazyHai
#
#                                                    Tweet  polarity     label
# 25157  The laser show at Dandi Kutir is wonderful! \n...  0.866667  positive
# 13545  @BJP4India @narendramodi @AmitShah @arunjaitle...  0.377273  positive
# 8453   Someone has 2 tell Narendra Modi @narendramodi...  0.145833  positive
# 13495  Look at the “Zameen &amp; Asmaan” Difference:\... -0.125000  negative
# 5406   @CNNnews18 @bhupendrachaube @ncbn Andhra was t...  0.500000  positive

# %%
rahul.sample(5)
# Out:
#        Unnamed: 0            User  \
# 11240       11240      roarDworld
# 9536         9536    ashish280287
# 11845       11845  LaksshyaAdvani
# 6930         6930      J_saraswat
# 9626         9626         lkpahwa
#
#                                                    Tweet  polarity     label
# 11240  @RahulGandhi where you see Theatre in PM annou...  0.750000  positive
# 9536   This whole seat sharing fiasco by @ArvindKejri...  0.490625  positive
# 11845  @BDUTT @smritiirani @RahulGandhi @smritiirani ...  0.250000  positive
# 6930   Can #PriyankaVadra revive #INC? How long will ...  0.225000  positive
# 9626   @RahulGandhi @OmarAbdullah @ncbn @ArvindKejriw... -0.200000  negative

# %%
neutral_modi=modi[modi['polarity']==0.0000]

# %%
remove_neutral_modi=modi['polarity'].isin(neutral_modi['polarity'])
modi.drop(modi[remove_neutral_modi].index,inplace=True)

# %%
neutral_rahul=rahul[rahul['polarity']==0.000]

remove_neutral_rahul=rahul['polarity'].isin(neutral_rahul['polarity'])
rahul.drop(rahul[remove_neutral_rahul].index,inplace=True)

# %%
print(rahul.shape,modi.shape)
# Out:
# (9367, 5) (17481, 5)

# %%
#modi dataset
'''np.random.seed(10)
remove_n= 8481

drop_indices=np.random.choice(modi.index,remove_n,replace=False)
df_modi=modi.drop(drop_indices)'''
# Out:
# 'np.random.seed(10)\nremove_n= 8481\n\ndrop_indices=np.random.choice(modi.index,remove_n,replace=False)\ndf_modi=modi.drop(drop_indices)'

# %%
'''np.random.seed(10)
remove_m=367

drop_indices=np.random.choice(rahul.index,remove_m,replace=False)
df_rahul=rahul.drop(drop_indices)'''
# Out:
# 'np.random.seed(10)\nremove_m=367\n\ndrop_indices=np.random.choice(rahul.index,remove_m,replace=False)\ndf_rahul=rahul.drop(drop_indices)'

# %%
#print(df_modi.shape,df_rahul.shape)

# %% [markdown]
# PREDICTION ABOUT INDIAN ELECTION

# %%
modi_count=modi.groupby('label').count()
modi_count
# Out:
#           Unnamed: 0   User  Tweet  polarity
# label
# negative        5036   5036   5036      5036
# positive       12445  12445  12445     12445

# %%
modi_count=modi.groupby('label').count()
negative_people_about_modi=modi_count['polarity'][0]
positive_people_about_modi=modi_count['polarity'][1]

print(negative_people_about_modi,positive_people_about_modi)
# Out:
# 5036 12445

# %%
#In percentage

negative_modi=(negative_people_about_modi/17481)*100
positive_modi=(positive_people_about_modi/17481)*100

negative_modi,positive_modi
# Out:
# (28.80842057090555, 71.19157942909445)

# %%
rahul_count=rahul.groupby('label').count()
rahul_count
# Out:
#           Unnamed: 0  User  Tweet  polarity
# label
# negative        3169  3169   3169      3169
# positive        6198  6198   6198      6198

# %%
rahul_count=rahul.groupby('label').count()
negative_people_about_rahul=rahul_count['polarity'][0]
positive_people_about_rahul=rahul_count['polarity'][1]

# %%
#In percentage

negative_rahul=(negative_people_about_rahul/9367)*100
positive_rahul=(positive_people_about_rahul/9367)*100

print(positive_rahul,negative_rahul)
# Out:
# 66.16846375573823 33.83153624426177

# %%
politicians=['rahul','modi']

neg_list=[negative_rahul,negative_modi]
pos_list=[positive_rahul,positive_modi]

fig=go.Figure(
    data=[
        go.Bar(name='negative',x=politicians,y=neg_list),
        go.Bar(name='positive',x=politicians,y=pos_list)
    ]
)

fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
